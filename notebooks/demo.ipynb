# %%
# Instalacja (dla Colab/Binder)
import subprocess, sys
subprocess.run([sys.executable, '-m', 'pip', 'install', 'rse-hello-numba-demo'], check=True)

# %%
from rse_hello_numba_demo import hello, add_distances
from pint import UnitRegistry

ureg = UnitRegistry()

# %%
print(hello())

# %%
# Przykład: dodawanie różnych jednostek
result = add_distances(2 * ureg.kilometer, 300 * ureg.meter)
print(f'2 km + 300 m = {result}')

# %%
# Konwersja jednostek
distance = 5 * ureg.mile
in_km = distance.to('kilometer')
print(f'5 miles = {in_km:.3f}')
